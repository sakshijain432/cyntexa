-- %%
create table dev.demo.beta (id int, name string) using iceberg

-- %%
desc extended dev.demo.beta

-- %%
describe dev.demo.drivers

-- %%
describe extended dev.demo.drivers

-- %%
desc detail dev.demo.drivers

-- %%
desc history dev.demo.drivers

-- %%
desc extended dev.demo.beta
