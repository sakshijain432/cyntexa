# %% [markdown]
# CTAS - CREATE TABLE

# %%
# %sql
Create table dev.demo.circuits_sql as
select * from read_files("/Volumes/dev/demo/raw-1000-richest/circuits.csv")

# %%
# %sql
Create table dev.demo.drivers_sql as
select * from read_files("/Volumes/dev/demo/raw-1000-richest/drivers.json")

# %%
# %sql
Create table dev.demo.financial_dataset_sql as
select * from read_files("/Volumes/dev/demo/raw-1000-richest/financial_dataset.csv")

# %%
# %sql
Create table dev.demo.part_sql as
select * from read_files("/Volumes/dev/demo/raw-1000-richest/part-00000-7951754c-3166-4cb7-8227-a5760c654c14-c000.snappy.parquet")

# %%
# %sql
select
  *
from
  dev.demo.part_sql

# %%
# %sql
create table dev.demo.drivers as
select code, dob, driverId, driverRef,name.forename, name.surname, nationality, number, _metadata.file_name, _metadata.file_path, current_timestamp() as ingestion_ts from read_files("/Volumes/dev/demo/raw-1000-richest/drivers.json",format=>"json")

# %%
# %sql
select * from dev.demo.drivers limit 100;
