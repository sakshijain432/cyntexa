# %%
# %sql
samples.show()
select franchiseID from sales_franchises

# %%
# %sql
create table dev.demo.customer;

# %%
# %sql
insert into dev.demo.customer values(1,'John','NY',10001),(2,'Jane','CA',90001),(3,'Bob','TX',78701),(4,'Alice','NY',10002),(5,'Charlie','CA',90002)

# %%
# %sql
use catalog `dev`; select * from `demo`.`customer` limit 100;

# %%
# %sql
CREATE FUNCTION dev.demo.customer(s STRING)
RETURNS STRING
return

# %%
# %sql
CREATE VIEW dev.default.active_employees AS
SELECT id, name, department 
FROM samples.information_schema.tables.
WHERE status = 'Active';
