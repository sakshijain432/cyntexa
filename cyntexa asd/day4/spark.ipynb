# %%
# %python
spark

# %%
# %python
spark.version

# %%
employees = [{"name": "John D.", "age": 30},
  {"name": "Alice G.", "age": 25},
  {"name": "Bob T.", "age": 35},
  {"name": "Eve A.", "age": 28}]

df = spark.createDataFrame(employees)

# %%
df.show()

# %%
df.display()
#it only works in databricks

# %% [markdown]
# Lazy evaluation

# %%
df = spark.read.csv("/Volumes/dev/demo/raw-1000-richest/financial_dataset.csv")

# %%
df.display()

# %%
df = spark.read.csv("/Volumes/dev/demo/raw-1000-richest/financial_dataset.csv", header=True,inferSchema=True)

# %%
df.display()

# %% [markdown]
# Internal decsion making of spark like this -

# %%
df.filter("AccountType='Loan'").explain(True)

# %%
df.filter("AccountType='Loan'").display()

# %% [markdown]
# read and write different type of file

# %%
df = spark.read.csv("/Volumes/dev/demo/raw-1000-richest/financial_dataset.csv", header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("dev.demo.financial")

# %%
# %sql
select * from dev.demo.financial

# %%
(spark
 .read
 .csv("/Volumes/dev/demo/raw-1000-richest/financial_dataset.csv", header=True,inferSchema=True)  
 .write
 .mode("overwrite")
 .saveAsTable("dev.demo.financial"))
